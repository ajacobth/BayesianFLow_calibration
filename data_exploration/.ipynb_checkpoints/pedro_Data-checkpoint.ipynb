# %%
import pandas as pd
import numpy as np
import jax.numpy as jnp
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"] # Example: specify a serif font
})

# %%
df = pd.read_excel("Mat_time_pres_pos_data_1501.xlsx", header =None, sheet_name= "Pressure")               
df.head()
# Out:
#     0   1         2                        3                   4  \
# 0 NaN NaN       NaN                      NaN                 NaN
# 1 NaN NaN   Time(s)  Extruder Pressure (PSI)  Pump Pressure(PSI)
# 2 NaN NaN         0                687.94829          332.927429
# 3 NaN NaN  0.060966               721.002479          305.609107
# 4 NaN NaN  0.108939               747.514903          285.115698
#
#                 5   6   7                                     8
# 0             NaN NaN NaN                                   NaN
# 1  Temperature(C) NaN NaN  We only care about the Pump Pressure
# 2      279.594642 NaN NaN                                   NaN
# 3      279.594642 NaN NaN                                   NaN
# 4      279.594642 NaN NaN                                   NaN

# %%
subset = df.iloc[1:, 2:6]
# Make the first row the header

new_header = subset.iloc[0]   # get the first row
subset = subset[1:]           # take the data after the header row
subset.columns = new_header   # set header
subset = subset.reset_index(drop=True)  # clean index
print(subset.head())
# Out:
# 1   Time(s) Extruder Pressure (PSI) Pump Pressure(PSI) Temperature(C)
# 0         0               687.94829         332.927429     279.594642
# 1  0.060966              721.002479         305.609107     279.594642
# 2  0.108939              747.514903         285.115698     279.594642
# 3  0.154912               767.74587         270.662268     279.594642
# 4  0.200885              781.886558          261.56303     279.594642

# %%
pressure = subset['Pump Pressure(PSI)'].values[1:]
pressure_times = subset['Time(s)'].values[1:]

# %%
df= pd.read_excel("Mat_time_pres_pos_data_1501.xlsx", header =None, sheet_name= "Position")
df.head()
columns_to_drop = [0, 1,7, 9, 10, 11, 12]

df.drop(df.columns[columns_to_drop], axis=1, inplace=True)


subset = df.iloc[1:, :]
new_header = subset.iloc[0]
subset.columns = new_header
subset = subset.reset_index(drop=True)  # clean index
subset.head()
# Out:
# 1  Time(seconds)  x(mm)  y(mm)  z(mm)  Speed (mm/s)  Flowrate[m^3/s]  \
# 0  Time(seconds)  x(mm)  y(mm)  z(mm)  Speed (mm/s)  Flowrate[m^3/s]
# 1              0 -38.25      0      0     32.941176              0.0
# 2           0.05 -38.25  -1.68      0          33.6              0.0
# 3          0.101 -38.25  -3.37      0     33.137255              0.0
# 4          0.151 -38.25  -5.05      0          33.6              0.0
#
# 1  Area of bead(mm^2)
# 0  Area of bead(mm^2)
# 1            8.809149
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
# xreate all the ararys 

time = subset['Time(seconds)'].values[1:]
x_locs = subset['x(mm)'].values[1:]
y_locs = subset['y(mm)'].values[1:]
z_locs = subset['z(mm)'].values[1:]
speeds = subset['Speed (mm/s)'].values[1:]
flow_rates = subset['Flowrate[m^3/s]'].values[1:]

flow_rates
# Out:
# array([2.9018373537004547e-07, 2.9598741007745123e-07,
#        2.919110195091745e-07, ..., 8.882156318965994e-07,
#        8.718936143188845e-07, 8.879762128984407e-07], dtype=object)

# %%
# check lengths

print(pressure.shape)
print(speeds.shape)

print(time.shape)

print(time)
# Out:
# (8234,)
# (8406,)
# (8406,)
# [0 0.0500000000000007 0.100999999999999 ... 424.267 424.318 424.368]

# %% [markdown]
# ## lets make some plots

# %%
fig, ax = plt.subplots(1,1, figsize = (12, 4))
ax.plot(pressure_times, pressure)
ax.set_xlabel('Time(s)', fontsize=14)
ax.set_ylabel('Pressure (Pa)', fontsize=14)
ax.grid()

# %% [markdown]
# ## Going to normalize the y axis of pressure and speeds so that I can compare them

# %%
def normalize(x:np.array)->np.array:
    return (x- np.min(x))/(np.max(x)- np.min(x))
                           
fig, ax = plt.subplots(1,1, figsize=(12, 4))

ax.plot(time, normalize(flow_rates), '--',label = 'Flow Rate')
#ax.plot(time, normalize(speeds), label = 'Speeds')
ax.plot(pressure_times, normalize(pressure), label = 'Pressure')

ax.set_xlabel('Time(s)', fontsize=14)
ax.legend(loc='best', fontsize=14)
ax.set_ylabel('Normalized Flow Rate/Pressure', fontsize=14)
ax.set_title('Visualization of pressure changes to set flow rates')
plt.savefig('pressure_speed_vs_time.pdf')
#plt.plot(pressure[:600])

# %% [markdown]
# # will start processing data here

# %%
time 
x_locs 
y_locs 
z_locs 
speeds 
flow_rates 
pressure
pressure_times

layer = 4
layer_height = 1.5  # in mm
extract_flow = 8.897e-7 # 4.84503201019647e-07 #8.897e-7
flow_sensor_error_percentage = 5.
extract_flow_min = extract_flow - extract_flow*flow_sensor_error_percentage*0.01
extract_flow_max = extract_flow + extract_flow*flow_sensor_error_percentage*0.01
    

# extract layer first - just layer 1 for now
mask = np.argwhere((z_locs >= layer_height*(layer-1)) & (z_locs < layer_height*layer)).flatten()
times_layer = time[mask]
speeds_layer = speeds[mask]
flow_rates_layer = flow_rates[mask]

# maks flow rate
mask_flow_rates = np.argwhere((flow_rates_layer>=extract_flow_min) & (flow_rates_layer<=extract_flow_max))
times_speeds = times_layer[mask_flow_rates]
flow_rates_ss = flow_rates_layer[mask_flow_rates]


# find corresponding pressure profiles
time_range = np.array([np.min(times_speeds),np.max(times_speeds) ])
mask_pressures = np.argwhere((pressure_times >= time_range[0]) & (pressure_times <= time_range[1]))
pressure_times_ss = pressure_times[mask_pressures]
pressures_ss = pressure[mask_pressures]

print(pressure_times >= time_range[0])
# Out:
# [False False False ...  True  True  True]

# %%
def quantile_resample(a, target_len):
    """ Upsample or downsample array a to target_len preserving distribution."""
    q = np.linspace(0, 1, target_len)
    return np.quantile(a, q)

# cleaned version of my code above from CHATGPT
def extract_layer_data(layer: int,
                       layer_height: float,
                       z_locs: np.ndarray,
                       time: np.ndarray,
                       speeds: np.ndarray,
                       flow_rates: np.ndarray,
                       pressure_times: np.ndarray,
                       pressure: np.ndarray,
                       extract_flow: float,
                       flow_sensor_error_percentage: float = 5.0):
    """
    Extracts steady-state flow and corresponding pressure data for a given layer.

    Parameters
    ----------
    layer : int
        Layer number (1-indexed).
    layer_height : float
        Height of one layer in mm.
    z_locs : np.ndarray
        Array of z-locations (same length as `time` and `flow_rates`).
    time : np.ndarray
        Array of timestamps for flow measurements.
    speeds : np.ndarray
        Array of speeds corresponding to each time.
    flow_rates : np.ndarray
        Array of flow rate measurements.
    pressure_times : np.ndarray
        Array of timestamps for pressure measurements.
    pressure : np.ndarray
        Array of pressure values.
    extract_flow : float
        Expected flow rate to extract steady-state region.
    flow_sensor_error_percentage : float, optional
        Allowed sensor error in %, default 5%.

    Returns
    -------
    dict
        Dictionary containing:
        - 'times_speeds': np.ndarray of times during steady-state
        - 'flow_rates_ss': np.ndarray of steady-state flow rates
        - 'pressure_times_ss': np.ndarray of matching pressure times
        - 'pressures_ss': np.ndarray of matching pressure values
        - 'mask_flow_rates': np.ndarray of indices of steady-state flow points
    """

    # Compute allowed flow rate range
    extract_flow_min = extract_flow * (1 - 0.01 * flow_sensor_error_percentage)
    extract_flow_max = extract_flow * (1 + 0.01 * flow_sensor_error_percentage)

    # Extract layer
    mask_layer = np.argwhere(
        (z_locs >= layer_height * (layer - 1)) & (z_locs < layer_height * layer)
    ).flatten()
    times_layer = time[mask_layer]
    speeds_layer = speeds[mask_layer]
    flow_rates_layer = flow_rates[mask_layer]

    # Steady-state flow mask
    mask_flow = np.argwhere(
        (flow_rates_layer >= extract_flow_min) & (flow_rates_layer <= extract_flow_max)
    ).flatten()
    times_speeds = times_layer[mask_flow]
    flow_rates_ss = flow_rates_layer[mask_flow]

    # Matching pressure segment
    if len(times_speeds) > 0:
        time_range = np.array([np.min(times_speeds), np.max(times_speeds)])
        mask_pressure = np.argwhere(
            (pressure_times >= time_range[0]) & (pressure_times <= time_range[1])
        ).flatten()
        pressure_times_ss = pressure_times[mask_pressure]
        pressures_ss = pressure[mask_pressure]
    else:
        pressure_times_ss = np.array([])
        pressures_ss = np.array([])

    return {
        "times_speeds": times_speeds,
        "flow_rates_ss": flow_rates_ss,
        "pressure_times_ss": pressure_times_ss,
        "pressures_ss": pressures_ss,
        "mask_flow_rates": mask_flow,
    }

# %%
layer_sp = 2
extract_flow_sp =  6.87113630536953e-07 # 2.91582835522733e-07 # 8.89724060054260e-07 # 2.91582835522733e-07 # 
result = extract_layer_data(
    layer=layer_sp,
    layer_height=1.5,
    z_locs=z_locs,
    time=time,
    speeds=speeds,
    flow_rates=flow_rates,
    pressure_times=pressure_times,
    pressure=pressure,
    extract_flow=extract_flow_sp,
    flow_sensor_error_percentage=5.0,
)

# Unpack results
pressure_times_ss = result["pressure_times_ss"]
pressures_ss = result["pressures_ss"]

# %%
pressure_times_ss.shape
# Out:
# (114,)

# %% [markdown]
# ## If I take the middle section of the time series

# %%
fig, ax = plt.subplots(figsize=(6, 4))

# Compute middle 50% of time-based data
n = len(pressure_times_ss)
start = int(0.25 * n)
end = int(0.75 * n)

middle_times = pressure_times_ss[start:end]
middle_pressures = pressures_ss[start:end]

# Plot full and middle sections
ax.plot(pressure_times_ss, pressures_ss, 'o', alpha=0.4, label='All data')
ax.plot(middle_times, middle_pressures, 'o', color='red', label='Middle 50% (time)')

# Labels and legend
ax.set_xlabel('Time', fontsize = 14)
ax.set_ylabel('Pressure', fontsize = 14)
ax.legend()

# Dynamic title
ax.set_title(
    f"Layer {layer_sp} — Flow Rate = {extract_flow_sp:.3e} m³/s ±{5:.0f}%",
    fontsize=14,
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot runing average

# %%
# Clean & prepare data
x = np.asarray(middle_pressures, dtype=float)
x = x[np.isfinite(x)]
n = np.arange(1, x.size + 1, dtype=float)

# Running mean
cumsum = np.cumsum(x, dtype=float)
running_mean = cumsum / n

# Running (sample) variance -> SEM -> 95% CI
cumsq = np.cumsum(x**2, dtype=float)
var = np.empty_like(x, dtype=float)
var[:] = np.nan
# sample variance for k>=2: s_k^2 = (sum(x^2) - k*mean^2)/(k-1)
var[1:] = (cumsq[1:] - n[1:] * running_mean[1:]**2) / (n[1:] - 1)
sem = np.sqrt(var) / np.sqrt(n)
ci_low = running_mean - 1.96 * sem
ci_high = running_mean + 1.96 * sem

# Plot
fig, ax = plt.subplots(figsize=(6, 4))
ax.plot(running_mean, '-o', lw=1.5, color='tab:blue', label='Running mean')
# Shade CI only where it's defined (k>=2)
k = np.arange(x.size)
valid = k >= 1
ax.fill_between(k[valid], ci_low[valid], ci_high[valid], color='tab:blue', alpha=0.2,
                label='95\% CI')

ax.set_xlabel('No. of Points')
ax.set_ylabel('Running Average Pressure')
ax.set_title(f'Running Mean Convergence — Layer {layer_sp}, Flow = {extract_flow_sp:.3e} m³/s')
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Upsample to larger length

# %%
middle_pressures_resampled = quantile_resample(middle_pressures, 263)

# %% [markdown]
# # Compare re sampled mean to actual mean

# %%
def running_mean_with_ci(data):
    # Coerce to float and drop non-finite values
    x = np.asarray(data, dtype=float)
    mask = np.isfinite(x)
    x = x[mask]
    if x.size == 0:
        raise ValueError("No finite values in input.")

    # Cumulative mean
    n = np.arange(1, x.size + 1, dtype=float)
    cumsum = np.cumsum(x, dtype=float)
    cummean = cumsum / n

    # Incremental std (Welford) -> SEM -> 95% CI
    mean = 0.0
    m2 = 0.0
    std = np.empty_like(x, dtype=float)
    for i, val in enumerate(x, start=1):
        delta = val - mean
        mean += delta / i
        m2 += delta * (val - mean)
        std[i-1] = 0.0 if i < 2 else np.sqrt(m2 / (i - 1))
    sem = std / np.sqrt(n)
    lower = cummean - 1.96 * sem
    upper = cummean + 1.96 * sem
    return cummean, lower, upper

# --- compute running mean for original ---
m_orig, lo_orig, hi_orig = running_mean_with_ci(middle_pressures)

# --- compute final means only ---
mean_orig = np.mean(middle_pressures)
mean_res = np.mean(middle_pressures_resampled)

# --- plot ---
fig, ax = plt.subplots(figsize=(7, 4.5))
x_o = np.arange(1, len(m_orig) + 1)

# Running mean + CI (original)
ax.plot(x_o, m_orig, lw=1.6, color='tab:blue', label='Running mean (original)')
ax.fill_between(x_o, lo_orig, hi_orig, color='tab:blue', alpha=0.2)

# Final means (horizontal lines)
ax.axhline(mean_orig, color='black', ls='--', lw=1.5,
           label=f'Final mean (original): {mean_orig:.3f}')
ax.axhline(mean_res, color='red', ls='--', lw=1.5,
           label=f'Final mean (resampled): {mean_res:.3f}')

# Labels and title
ax.set_xlabel('No. of Points', fontsize=12)
ax.set_ylabel('Running Average Pressure', fontsize=12)
ax.set_title(
    f'Running Mean (Original) with 95\% CI — Layer {layer_sp}, Flow = {extract_flow_sp:.3e} m³/s',
    fontsize=13
)
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # comapre histograms

# %%
plt.figure(figsize=(6, 4))
plt.hist(middle_pressures, bins=30, alpha=0.5, label='Original', density=True)
plt.hist(middle_pressures_resampled, bins=30, alpha=0.5, label='Resampled', density=True)
plt.xlabel('Pressure', fontsize=14)
plt.ylabel('Density', fontsize=14)
plt.title('Original vs Resampled Pressure Distribution', fontsize=14)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Lets look at differences of the pressures across the layers

# %%
import numpy as np
import matplotlib.pyplot as plt

flows = np.array([
    2.91582835522733e-07,
    4.84503201019647e-07,
    6.87113630536953e-07,
    8.89724060054260e-07,
], dtype=float)

# a helper finction to get the middle 50%
def middle50_slice(n: int):
    i0 = int(0.25 * n)
    i1 = max(int(0.75 * n), i0 + 1)
    return i0, i1

def steady_mean_of_segment(times: np.ndarray, pressures: np.ndarray):
    """mean and standard error from the middle 50% of the time segment."""
    times = np.asarray(times)
    pressures = np.asarray(pressures, dtype=float)

    i0, i1 = middle50_slice(len(pressures))
    x = pressures[i0:i1]

    m = np.mean(x)
    s = np.std(x, ddof=1) if x.size > 1 else np.nan
    se = s / np.sqrt(x.size) if x.size > 1 else np.nan
    return m, se

# ---------- collect per-layer steady means ----------
n_layers = 14
means = np.full((n_layers, 4), np.nan)
sems  = np.full((n_layers, 4), np.nan)

for layer in range(1, n_layers + 1):
    for k, flow in enumerate(flows):
        res = extract_layer_data(
            layer=layer,
            layer_height=1.5,
            z_locs=z_locs,
            time=time,
            speeds=speeds,
            flow_rates=flow_rates,
            pressure_times=pressure_times,
            pressure=pressure,
            extract_flow=flow,
            flow_sensor_error_percentage=5.0,
        )
        pt = res["pressure_times_ss"]
        pv = res["pressures_ss"]

        m, se = steady_mean_of_segment(pt, pv)
        means[layer-1, k] = m
        sems[layer-1, k]  = se

# ---------- consecutive differences & error propagation ----------
# Δ12 = F2 - F1, Δ23 = F3 - F2, Δ34 = F4 - F3
d12 = means[:, 1] - means[:, 0]
d23 = means[:, 2] - means[:, 1]
d34 = means[:, 3] - means[:, 2]

# standard across the differnce
sd12 = np.sqrt(sems[:, 1]**2 + sems[:, 0]**2)
sd23 = np.sqrt(sems[:, 2]**2 + sems[:, 1]**2)
sd34 = np.sqrt(sems[:, 3]**2 + sems[:, 2]**2)

layers = np.arange(1, n_layers + 1)

# ---------- plot ----------
fig, ax = plt.subplots(figsize=(8, 4.8))

ax.errorbar(layers, d12, yerr=sd12, fmt='o-', capsize=3, color='r', label=r'$\Delta 12$: F2 - F1')
ax.errorbar(layers, d23, yerr=sd23, fmt='s-', capsize=3,  color='g',label=r'$\Delta 23$: F3 - F2')
ax.errorbar(layers, d34, yerr=sd34, fmt='^-', capsize=3,  color='k',label=r'$\Delta 34$: F4 - F3')

# horizontal means for quick visual test
for d, name, ls, color in [
    (d12, r'$\Delta 12$ mean', ':', 'r'),
    (d23, r'$\Delta 23$ mean', '--', 'g'),
    (d34, r'$\Delta 34$ mean', '-.', 'k'),
]:
    mu = np.nanmean(d)
    ax.axhline(mu, linestyle=ls, alpha=0.4, color=color,label=fr'{name} = {mu:.3f}')

ax.set_xlabel('Layer', fontsize=12)
ax.set_ylabel('Pressure difference', fontsize=12)
ax.set_title('Consecutive flow-rate pressure differences across layers', fontsize=13)
ax.legend(ncol=2)
ax.grid(alpha=0.2)
plt.tight_layout()
plt.show()

# ---------- quick numeric summary ----------
def summarize(name, d, sd):
    valid = np.isfinite(d)
    mu = np.nanmean(d)
    sdv = np.nanstd(d, ddof=1)
    print(f"{name}: mean={mu:.4f}, std_across_layers={sdv:.4f}, "
          f"n={valid.sum()}, median_SE={np.nanmedian(sd):.4f}")

summarize(r"\Delta 12", d12, sd12)
summarize(r"\Delta 23", d23, sd23)
summarize(r"\Delta 34", d34, sd34)
# Out:
# \Delta 12: mean=83.8088, std_across_layers=26.0888, n=14, median_SE=0.6507
# \Delta 23: mean=83.4049, std_across_layers=19.4580, n=14, median_SE=0.6584
# \Delta 34: mean=65.9743, std_across_layers=5.6731, n=14, median_SE=0.9143

# %% [markdown]
# ## Trial things below here

# %% [markdown]
# ## If I take the middle section of the pressure series (50]% precentile)

# %%
import matplotlib.pyplot as plt

# Unpack from result
pressure_times_ss = result["pressure_times_ss"]
pressures_ss = result["pressures_ss"]

# Compute middle 50% (optional, can remove if not needed)
q1, q3 = np.percentile(pressures_ss, [25, 75])
mask_middle = (pressures_ss >= q1) & (pressures_ss <= q3)
middle_pressures = pressures_ss[mask_middle]
middle_times = pressure_times_ss[mask_middle]

# Plot
fig, ax = plt.subplots(figsize=(6, 4))
ax.plot(pressure_times_ss, pressures_ss, 'o', alpha=0.4, label='All data')
ax.plot(middle_times, middle_pressures, 'o', color='red', label='Middle 50%')

# Labels and legend
ax.set_xlabel('Time', fontsize = 14)
ax.set_ylabel('Pressure', fontsize = 14)
ax.legend()

# Dynamic title
ax.set_title(
    f"Layer {layer_sp} — Flow Rate = {extract_flow_sp:.3e} m³/s ±{5:.0f}%",
    fontsize=14,
)

ax.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Compute running average (cumulative mean)
running_mean = np.cumsum(middle_pressures) / np.arange(1, len(middle_pressures) + 1)

# Plot running average
fig, ax = plt.subplots(figsize=(6, 4))
ax.plot(running_mean, '-o', lw=1.5, color='tab:blue')
ax.set_xlabel('No: Points')
ax.set_ylabel('Running Average Pressure')
ax.set_title(
    f'Running Mean Convergence — Layer {layer_sp}, Flow = {extract_flow_sp:.3e} m³/s'
)
plt.tight_layout()
plt.show()

# %%
plt.hist(middle_pressures)
# Out:
# (array([19., 20., 20., 12., 14., 13.,  9.,  7.,  6., 11.]),
#  array([213.645259 , 215.3989221, 217.1525852, 218.9062483, 220.6599114,
#         222.4135745, 224.1672376, 225.9209007, 227.6745638, 229.4282269,
#         231.18189  ]),
#  <BarContainer object of 10 artists>)
